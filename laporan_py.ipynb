# %% [markdown]
# <a href="https://colab.research.google.com/github/Tegar348/Jobsheet-09-Modular-Programming-Import-From-Library-Standar-/blob/main/laporan_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile laporan.py

def tampilkan_skor(total_skor, jumlah_soal):
  """Menampilkan ringkasan skor kuis."""
  print(f"\n--- Ringkasan Skor ---")
  print(f"Anda memperoleh skor {total_skor} dari {jumlah_soal} soal.")
  print(f"Persentase skor: {(total_skor / jumlah_soal) * 100:.2f}%")
# Out:
# Writing laporan.py
